# %%
import pandas as pd

# %%
df=pd.read_csv("student_random_data.csv")
print(df)
# Out:
#        Name  Roll No  Marks
# 0     Kavya   201001     47
# 1     Suman   201002     44
# 2     Sneha   201003     75
# 3    Vikram   201004     93
# 4     Swati   201005     76
# 5     Deepa   201006     52
# 6      Sana   201007     43
# 7     Tanya   201008     92
# 8    Simran   201009     77
# 9     Karan   201010     49
# 10    Aarav   201011     98
# 11      Dev   201012     56
# 12     Aman   201013     61
# 13   Suresh   201014     67
# 14    Leela   201015     35
# 15    Akash   201016     63
# 16    Priya   201017     87
# 17    Tanvi   201018     40
# 18  Bhavana   201019     64
# 19    Aditi   201020     71
# 20   Rakesh   201021     84
# 21   Manish   201022     36
# 22    Ankit   201023     62
# 23    Arjun   201024     56
# 24    Pooja   201025     46
# 25    Rohan   201026     53
# 26    Pavan   201027     64
# 27   Monika   201028     84
# 28     Diya   201029     72
# 29    Gauri   201030     98
# 30   Sameer   201031     94
# 31     Neha   201032     58
# ...

# %% [markdown]
# Average of Marks

# %%
avg_marks=df['Marks'].mean()
print(avg_marks)
# Out:
# 67.02

# %% [markdown]
# Toppers

# %%
tp=df[df['Marks']>avg_marks]
tp
# Out:
#        Name  Roll No  Marks
# 2     Sneha   201003     75
# 3    Vikram   201004     93
# 4     Swati   201005     76
# 7     Tanya   201008     92
# 8    Simran   201009     77
# 10    Aarav   201011     98
# 16    Priya   201017     87
# 19    Aditi   201020     71
# 20   Rakesh   201021     84
# 27   Monika   201028     84
# 28     Diya   201029     72
# 29    Gauri   201030     98
# 30   Sameer   201031     94
# 32     Isha   201033     82
# 33    Meera   201034     90
# 35    Ishan   201036     74
# 38  Krishna   201039     85
# 39   Harsha   201040     76
# 41    Varun   201042     78
# 42    Kiran   201043     72
# 43   Nikhil   201044     87
# 45   Ananya   201046     70
# 46    Rahul   201047     99
# 48     Teja   201049     93
